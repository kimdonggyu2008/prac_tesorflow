# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/코딩공부/텐서플로우 공부/prac_tesorflow
# Out:
# /content/drive/MyDrive/코딩공부/텐서플로우 공부/prac_tesorflow

# %%
# !git config --global user.email 'dkkim2008@naver.com'
# !git config --global user.name 'kimdonggyu2008'

# %%
# !git add --all

# %%
# !git commit -m '완료됨'
# !git push
# Out:
# [main 82b2ec7] 완료됨
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  rename Untitled0.ipynb => git_update.ipynb (56%)
#  create mode 100644 "\341\204\211\341\205\245\341\206\253\341\204\222\341\205\247\341\206\274\341\204\222\341\205\254\341\204\200\341\205\261_\341\204\216\341\205\254\341\204\211\341\205\251\341\204\217\341\205\251\341\204\211\341\205\263\341\204\220\341\205\263.ipynb"
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 240.26 KiB | 6.16 MiB/s, done.
# Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/kimdonggyu2008/prac_tesorflow.git
#    a7d75ed..82b2ec7  main -> main
