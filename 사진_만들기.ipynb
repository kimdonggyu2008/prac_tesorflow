# %% [markdown]
# <a href="https://colab.research.google.com/github/kimdonggyu2008/prac_tesorflow/blob/main/%EC%82%AC%EC%A7%84_%EB%A7%8C%EB%93%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.9/362.9 kB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.1 MB/s eta 0:00:00
# ...

# %%
# Note: DALL-E 3 requires version 1.0.0 of the openai-python library or later
import os
from openai import AzureOpenAI
import json

client = AzureOpenAI(
    api_version="2024-05-01-preview",
    azure_endpoint="https://helloaidevlabopenai.openai.azure.com/",
    api_key='87bc56304a2047f48da379864f738b49',
)

result = client.images.generate(
    model="dev-dall-e-3", # the name of your DALL-E 3 deployment
    prompt="면접을 보고있는 면접관의 모습을 그려줘 ",
    n=1
)

image_url = json.loads(result.model_dump_json())['data'][0]['url']
print(image_url)
# Out:
# https://dalleprodsec.blob.core.windows.net/private/images/7dd5abef-60e1-4843-875e-834481dc5708/generated_00.png?se=2024-08-23T01%3A34%3A16Z&sig=u9AShnnFdBwRdMYs1qnWg2WDFUlP%2BuVzj8mx0jjU0%2BE%3D&ske=2024-08-28T12%3A59%3A24Z&skoid=e52d5ed7-0657-4f62-bc12-7e5dbb260a96&sks=b&skt=2024-08-21T12%3A59%3A24Z&sktid=33e01921-4d64-4f8c-a055-5bdaffd5e33d&skv=2020-10-02&sp=r&spr=https&sr=b&sv=2020-10-02

# %%
from PIL import Image
from io import BytesIO
import requests

response=requests.get(image_url)
image=Image.open(BytesIO(response.content))

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>
